# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
train = pd.read_csv('train_values.csv')
train_label = pd.read_csv('train_labels.csv')

# %%
train.shape,train_label.shape
# Out:
# ((500000, 22), (500000, 2))

# %%
train.head()
# Out:
#    row_id  loan_type  property_type  loan_purpose  occupancy  loan_amount  \
# 0       0          3              1             1          1         70.0
# 1       1          1              1             3          1        178.0
# 2       2          2              1             3          1        163.0
# 3       3          1              1             1          1        155.0
# 4       4          1              1             1          1        305.0
#
#    preapproval  msa_md  state_code  county_code      ...       applicant_sex  \
# 0            3      18          37          246      ...                   1
# 1            3     369          52          299      ...                   1
# 2            3      16          10          306      ...                   1
# 3            1     305          47          180      ...                   1
# 4            3      24          37           20      ...                   2
#
# ...

# %%
train_label.head()
# Out:
#    row_id  accepted
# 0       0         1
# 1       1         0
# 2       2         1
# 3       3         1
# 4       4         1

# %%
train = pd.concat([train,train_label.accepted],axis=1)

# %%
train.shape
# Out:
# (500000, 23)

# %%
train.head()
# Out:
#    row_id  loan_type  property_type  loan_purpose  occupancy  loan_amount  \
# 0       0          3              1             1          1         70.0
# 1       1          1              1             3          1        178.0
# 2       2          2              1             3          1        163.0
# 3       3          1              1             1          1        155.0
# 4       4          1              1             1          1        305.0
#
#    preapproval  msa_md  state_code  county_code    ...     applicant_income  \
# 0            3      18          37          246    ...                 24.0
# 1            3     369          52          299    ...                 57.0
# 2            3      16          10          306    ...                 67.0
# 3            1     305          47          180    ...                105.0
# 4            3      24          37           20    ...                 71.0
#
# ...

# %%
train.accepted.value_counts()
# Out:
# 1    250114
# 0    249886
# Name: accepted, dtype: int64

# %%
seed = 42
X_train, X_test, y_train, y_test = train_test_split(train, train.accepted, test_size=0.2, random_state=seed)

# %%
len(X_train), len(X_test), len(y_train), len(y_test )
# Out:
# (320000, 80000, 320000, 80000)

# %%
import seaborn as sns

# %%
sns.countplot(y_test)

# %%
sns.countplot(y_train)

# %%
y_test.value_counts()
# Out:
# 0    40020
# 1    39980
# Name: accepted, dtype: int64

# %%
y_train.value_counts()
# Out:
# 0    160034
# 1    159966
# Name: accepted, dtype: int64

# %%
train = X_train
train.head()
# Out:
#         row_id  loan_type  property_type  loan_purpose  occupancy  \
# 110049  110049          1              1             2          1
# 83668    83668          1              1             1          1
# 253898  253898          1              1             1          1
# 97905    97905          1              1             3          1
# 417495  417495          1              1             3          1
#
#         loan_amount  preapproval  msa_md  state_code  county_code    ...     \
# 110049         78.0            3      77          31           20    ...
# 83668         322.0            2     358          32            2    ...
# 253898        144.0            3     139           3          299    ...
# 97905         523.0            3     266          48           83    ...
# 417495        143.0            3     171          52          257    ...
#
#         applicant_income  population  minority_population_pct  \
# ...

# %%
test = X_test.drop(columns=['accepted'])
test.head()
# Out:
#         row_id  loan_type  property_type  loan_purpose  occupancy  \
# 304897  304897          2              1             3          1
# 386541  386541          1              1             2          1
# 453817  453817          1              1             3          1
# 352553  352553          3              1             1          1
# 273259  273259          1              1             1          1
#
#         loan_amount  preapproval  msa_md  state_code  county_code  \
# 304897        113.0            3     356           5           98
# 386541         10.0            3      10          34           11
# 453817        270.0            3      24          37           20
# 352553        514.0            3      10          34           11
# 273259         92.0            3     150          14            3
#
#             ...       applicant_sex  applicant_income  population  \
# 304897      ...                   1              47.0      3256.0
# ...

# %%
answer_key = pd.DataFrame(data=test.row_id,columns=['row_id'])
answer_key['accepted'] = y_test
answer_key.head()
# Out:
#         row_id  accepted
# 304897  304897         0
# 386541  386541         1
# 453817  453817         0
# 352553  352553         0
# 273259  273259         1

# %%
type((answer_key.row_id).iloc[2])
# Out:
# numpy.int64

# %%
answer_key.accepted.value_counts()
# Out:
# 0    40020
# 1    39980
# Name: accepted, dtype: int64

# %%
train.to_csv('train.csv',index=False)
test.to_csv('test.csv',index=False)
#sample_submission.to_csv('sample_submission.csv',index=False)
answer_key.to_csv('answer_key.csv',index=False)
